# %% [markdown]
# <a href="https://colab.research.google.com/github/soumyadipkarforma03/python-sem1/blob/main/selflearn_10_09_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Self Learn**
# 10.09.2026

# %% [markdown]
# ## Comments

# %% [markdown]
# ### Single Line

# %%
# This is a single line comment
print("Single line comment")
# Out:
# Single line comment

# %% [markdown]
# ### Multi line comment

# %%
"""
This
is
a multi
line comment
"""
print("Multi line comment")
# Out:
# Multi line comment

# %% [markdown]
# ## Variables

# %%
### assign multiple values
