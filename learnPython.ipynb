# %% [markdown]
# <a href="https://colab.research.google.com/github/soumyadipkarforma03/python-sem1/blob/main/learnPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **# Python Tutorial**

# %%
print("Hello")
# Out:
# Hello
